# %% [markdown]
# # Assignment 1

# %% [markdown]
# Extracting Time Series Properties of Glucose Levels in Artificial Pancreas

# %%
# imports
from datetime import datetime, time

# %%
# parse the csv file and find earliest auto switch
autoTimeStamp = ''
with open('InsulinData.csv', 'r') as f:    
    i = 0
    for line in f:
        i += 1
        if i == 1:
            continue
            
        arr = line.split(",")        
        if arr[16] == 'AUTO MODE ACTIVE PLGM OFF':
            autoTimeStamp = "{0}-{1}".format(arr[1], arr[2])
            
# confirm - answer is 40133
# confirm - date time stamp is 8/9/2017-8:07:13
print(autoTimeStamp)
# Out:
# 8/9/2017-8:07:13

# %%
'''
Collect time stamp + reading data
'''

timeReadingDict = {}
with open('CGMData.csv', 'r') as f:
    # using prev value if reading is missing
    prev = 130
    i = 0
    for line in f:
        # skip headers
        i += 1
        if i == 1:
            continue
            
        arr = line.split(",")
        dateTime = "{0}-{1}".format(arr[1], arr[2])
        reading = 0
        if arr[30] == '':
            reading = prev
        else:
            reading = int(arr[30])
            prev = reading
            
        timeReadingDict[dateTime] = reading
        
# print(timeReadingDict)

# %%
''' 
Collect readings by date 
'''

dateReadingListDict = {}

for time in timeReadingDict:
    date, clock = time.split('-')
    if date not in dateReadingListDict:
        dateReadingListDict[date] = {}
    dateReadingListDict[date][clock] = timeReadingDict[time]

'''
Splitting dates into auto and manual
'''

autoDatesReadingListDict = {}
manDatesReadingListDict = {}

switchDate = datetime.strptime(autoTimeStamp.split('-')[0], "%m/%d/%Y")
for date in dateReadingListDict:
    curr = datetime.strptime(date, "%m/%d/%Y")
    if curr >= switchDate:
        autoDatesReadingListDict[date] = dateReadingListDict[date]
    if curr <= switchDate:
        manDatesReadingListDict[date] = dateReadingListDict[date]

# print(dateReadingListDict['2/12/2018'])

# %%
'''
Create day and night partitions
Copy data from date reading into these partitions
'''

# dayDict = {}
# nightDict = {}
autoDayDict = {}
autoNightDict = {}
manDayDict = {}
manNightDict = {}
dayLimit = datetime.strptime("06:00:00", "%H:%M:%S")

# for date in dateReadingListDict:
#     for time in dateReadingListDict[date]:
#         curr = datetime.strptime(time, "%H:%M:%S")
#         if curr < dayLimit:
#             if date not in nightDict:
#                 nightDict[date] = {}
#             nightDict[date][time] = dateReadingListDict[date][time]
#         else:
#             if date not in dayDict:
#                 dayDict[date] = {}
#             dayDict[date][time] = dateReadingListDict[date][time]

for date in autoDatesReadingListDict:
    for time in autoDatesReadingListDict[date]:
        curr = datetime.strptime(time, "%H:%M:%S")
        if curr < dayLimit:
            if date not in autoNightDict:
                autoNightDict[date] = {}
            autoNightDict[date][time] = autoDatesReadingListDict[date][time]
        else:
            if date not in autoDayDict:
                autoDayDict[date] = {}
            autoDayDict[date][time] = autoDatesReadingListDict[date][time]
            
for date in manDatesReadingListDict:
    for time in manDatesReadingListDict[date]:
        curr = datetime.strptime(time, "%H:%M:%S")
        if curr < dayLimit:
            if date not in manNightDict:
                manNightDict[date] = {}
            manNightDict[date][time] = manDatesReadingListDict[date][time]
        else:
            if date not in manDayDict:
                manDayDict[date] = {}
            manDayDict[date][time] = manDatesReadingListDict[date][time]
# print(dayDict['2/11/2018'])

# %%
# '''
# Sum of whole Day segment - AUTO
# '''

# autoHrgList = []
# autoHrgCrtList = []
# autoRngList = []
# autoRsList = []
# autoHog1List = []
# autoHog2List = []

# for date in autoDatesReadingListDict:
#     hrgSum = 0
#     hrgCrtSum = 0
#     rngSum = 0
#     rsSum = 0
#     hog1Sum = 0
#     hog2Sum = 0
#     for reading in autoDatesReadingListDict[date].values():
#         if reading > 180:
#             hrgSum += 1
#         if reading > 250:
#             hrgCrtSum += 1
#         if reading >= 70 and reading <= 180:
#             rngSum += 1
#         if reading >= 70 and reading <= 150:
#             rsSum += 1
#         if reading < 70:
#             hog1Sum += 1
#         if reading < 54:
#             hog2Sum += 1
#     # for getting %
#     autoHrgList.append(hrgSum/2.88)
#     autoHrgCrtList.append(hrgCrtSum/2.88)
#     autoRngList.append(rngSum/2.88)
#     autoRsList.append(rsSum/2.88)
#     autoHog1List.append(hog1Sum/2.88)
#     autoHog2List.append(hog2Sum/2.88)
    
# # print(rngList[0:20])
# Out:
# [42.708333333333336, 70.13888888888889, 77.77777777777779, 54.51388888888889, 67.01388888888889, 66.31944444444444, 42.361111111111114, 77.08333333333334, 76.04166666666667, 68.75, 59.72222222222222, 54.51388888888889, 64.93055555555556, 29.51388888888889, 74.65277777777779, 84.72222222222223, 71.875, 67.01388888888889, 60.76388888888889, 77.08333333333334]

# %%
'''
Sum of whole Day segment - MANUAL
'''

manHrgList = []
manHrgCrtList = []
manRngList = []
manRsList = []
manHog1List = []
manHog2List = []

for date in manDatesReadingListDict:
    hrgSum = 0
    hrgCrtSum = 0
    rngSum = 0
    rsSum = 0
    hog1Sum = 0
    hog2Sum = 0
    for reading in manDatesReadingListDict[date].values():
        if reading > 180:
            hrgSum += 1
        if reading > 250:
            hrgCrtSum += 1
        if reading >= 70 and reading <= 180:
            rngSum += 1
        if reading >= 70 and reading <= 150:
            rsSum += 1
        if reading < 70:
            hog1Sum += 1
        if reading < 54:
            hog2Sum += 1
    # for getting %
    manHrgList.append(hrgSum/2.88)
    manHrgCrtList.append(hrgCrtSum/2.88)
    manRngList.append(rngSum/2.88)
    manRsList.append(rsSum/2.88)
    manHog1List.append(hog1Sum/2.88)
    manHog2List.append(hog2Sum/2.88)
    
# print(rngList[0:20])

# %%
'''
Sum of daytime segment - AUTO
'''

autoDayHrgList = []
autoDayHrgCrtList = []
autoDayRngList = []
autoDayRsList = []
autoDayHog1List = []
autoDayHog2List = []

for date in autoDayDict:
    hrgSum = 0
    hrgCrtSum = 0
    rngSum = 0
    rsSum = 0
    hog1Sum = 0
    hog2Sum = 0
    for reading in autoDayDict[date].values():
        if reading > 180:
            hrgSum += 1
        if reading > 250:
            hrgCrtSum += 1
        if reading >= 70 and reading <= 180:
            rngSum += 1
        if reading >= 70 and reading <= 150:
            rsSum += 1
        if reading < 70:
            hog1Sum += 1
        if reading < 54:
            hog2Sum += 1
    # for getting %
    autoDayHrgList.append(hrgSum/2.88)
    autoDayHrgCrtList.append(hrgCrtSum/2.88)
    autoDayRngList.append(rngSum/2.88)
    autoDayRsList.append(rsSum/2.88)
    autoDayHog1List.append(hog1Sum/2.88)
    autoDayHog2List.append(hog2Sum/2.88)
    
# print(dayRngList[0:20])
# Out:
# [28.819444444444446, 46.18055555555556, 57.29166666666667, 31.25, 44.79166666666667, 45.13888888888889, 25.0, 52.083333333333336, 59.375, 56.94444444444445, 51.736111111111114, 40.27777777777778, 43.05555555555556, 20.48611111111111, 52.43055555555556, 60.76388888888889, 52.083333333333336, 42.01388888888889, 40.27777777777778, 52.77777777777778]

# %%
'''
Sum of daytime segment - MANUAL
'''

manDayHrgList = []
manDayHrgCrtList = []
manDayRngList = []
manDayRsList = []
manDayHog1List = []
manDayHog2List = []

for date in manDayDict:
    hrgSum = 0
    hrgCrtSum = 0
    rngSum = 0
    rsSum = 0
    hog1Sum = 0
    hog2Sum = 0
    for reading in manDayDict[date].values():
        if reading > 180:
            hrgSum += 1
        if reading > 250:
            hrgCrtSum += 1
        if reading >= 70 and reading <= 180:
            rngSum += 1
        if reading >= 70 and reading <= 150:
            rsSum += 1
        if reading < 70:
            hog1Sum += 1
        if reading < 54:
            hog2Sum += 1
    # for getting %
    autoDayHrgList.append(hrgSum/2.88)
    autoDayHrgCrtList.append(hrgCrtSum/2.88)
    autoDayRngList.append(rngSum/2.88)
    autoDayRsList.append(rsSum/2.88)
    autoDayHog1List.append(hog1Sum/2.88)
    autoDayHog2List.append(hog2Sum/2.88)
    
# print(dayRngList[0:20])

# %%
ntHrgList = []
ntHrgCrtList = []
ntRngList = []
ntRsList = []
ntHog1List = []
ntHog2List = []

for date in nightDict:
    hrgSum = 0
    hrgCrtSum = 0
    rngSum = 0
    rsSum = 0
    hog1Sum = 0
    hog2Sum = 0
    for reading in nightDict[date].values():
        if reading > 180:
            hrgSum += 1
        if reading > 250:
            hrgCrtSum += 1
        if reading >= 70 and reading <= 180:
            rngSum += 1
        if reading >= 70 and reading <= 150:
            rsSum += 1
        if reading < 70:
            hog1Sum += 1
        if reading < 54:
            hog2Sum += 1
    # for getting %
    ntHrgList.append(hrgSum/2.88)
    ntHrgCrtList.append(hrgCrtSum/2.88)
    ntRngList.append(rngSum/2.88)
    ntRsList.append(rsSum/2.88)
    ntHog1List.append(hog1Sum/2.88)
    ntHog2List.append(hog2Sum/2.88)
    
print(ntRngList[0:20])
# Out:
# [13.88888888888889, 23.958333333333336, 20.48611111111111, 23.26388888888889, 22.22222222222222, 21.180555555555557, 17.36111111111111, 25.0, 16.666666666666668, 11.805555555555555, 7.986111111111112, 14.236111111111112, 21.875, 9.027777777777779, 22.22222222222222, 23.958333333333336, 19.791666666666668, 25.0, 20.48611111111111, 24.305555555555557]

# %%
# wholeAvgList = [hyper, hyperCrit, range, rangeSec, hypo1, hypo2]
wholeAvgList = [0,0,0,0,0,0]

for hrg in hrgList:
    wholeAvgList[0] += hrg
wholeAvgList[0] /= len(hrgList)

for hrgCrt in hrgCrtList:
    wholeAvgList[1] += hrgCrt
wholeAvgList[1] /= len(hrgCrtList)

for rng in rngList:
    wholeAvgList[2] += rng
wholeAvgList[2] /= len(rngList)

for rs in rsList:
    wholeAvgList[3] += rs
wholeAvgList[3] /= len(rsList)

for hog1 in hog1List:
    wholeAvgList[4] += hog1
wholeAvgList[4] /= len(hog1List)

for hog2 in hog2List:
    wholeAvgList[5] += hog2
# print(hog2Avg)
wholeAvgList[5] /= len(hog2List)

# print(wholeAvgList)

# %%
# dayAvgList = [hyper, hyperCrit, range, rangeSec, hypo1, hypo2]
dayAvgList = [0,0,0,0,0,0]

for hrg in dayHrgList:
    dayAvgList[0] += hrg
dayAvgList[0] /= len(dayHrgList)

for hrgCrt in dayHrgCrtList:
    dayAvgList[1] += hrgCrt
dayAvgList[1] /= len(dayHrgCrtList)

for rng in dayRngList:
    dayAvgList[2] += rng
dayAvgList[2] /= len(dayRngList)

for rs in dayRsList:
    dayAvgList[3] += rs
dayAvgList[3] /= len(dayRsList)

for hog1 in dayHog1List:
    dayAvgList[4] += hog1
dayAvgList[4] /= len(dayHog1List)

for hog2 in dayHog2List:
    dayAvgList[5] += hog2
dayAvgList[5] /= len(dayHog2List)

# dayAvgList = [hyper, hyperCrit, range, rangeSec, hypo1, hypo2]
ntAvgList = [0,0,0,0,0,0]

for hrg in ntHrgList:
    ntAvgList[0] += hrg
ntAvgList[0] /= len(ntHrgList)

for hrgCrt in ntHrgCrtList:
    ntAvgList[1] += hrgCrt
ntAvgList[1] /= len(ntHrgCrtList)

for rng in ntRngList:
    ntAvgList[2] += rng
ntAvgList[2] /= len(ntRngList)

for rs in ntRsList:
    ntAvgList[3] += rs
ntAvgList[3] /= len(ntRsList)

for hog1 in ntHog1List:
    ntAvgList[4] += hog1
ntAvgList[4] /= len(ntHog1List)

for hog2 in ntHog2List:
    ntAvgList[5] += hog2
ntAvgList[5] /= len(ntHog2List)

# %%
print(wholeAvgList)
print(dayAvgList)
print(ntAvgList)
# Out:
# [25.489672364672348, 6.0790598290598306, 68.40990028490029, 53.612891737891765, 4.645655270655269, 1.3461538461538463]
# [22.350427350427335, 5.614316239316241, 47.523148148148145, 35.56267806267807, 3.917378917378918, 1.1680911680911679]
# [3.1717760506620607, 0.469559585492228, 21.103195164076, 18.237262521588935, 0.7358232584916524, 0.17990788716177317]

# %%
'''
Calculate percentage for each metric for each date
Calculate mean of all percentages over date
Params:- Dict of date:{time:reading}
Return:- List of means of each metric
'''
def getMeanPercentageMetrics(in_data):
    hrgList = []
    hrgCrtList = []
    rngList = []
    rsList = []
    hog1List = []
    hog2List = []

    for date in in_data:
        hrgSum = 0
        hrgCrtSum = 0
        rngSum = 0
        rsSum = 0
        hog1Sum = 0
        hog2Sum = 0
        for reading in in_data[date].values():
            if reading > 180:
                hrgSum += 1
            if reading > 250:
                hrgCrtSum += 1
            if reading >= 70 and reading <= 180:
                rngSum += 1
            if reading >= 70 and reading <= 150:
                rsSum += 1
            if reading < 70:
                hog1Sum += 1
            if reading < 54:
                hog2Sum += 1
        # for getting %
        hrgList.append(hrgSum/2.88)
        hrgCrtList.append(hrgCrtSum/2.88)
        rngList.append(rngSum/2.88)
        rsList.append(rsSum/2.88)
        hog1List.append(hog1Sum/2.88)
        hog2List.append(hog2Sum/2.88)
    
    avgList = [0,0,0,0,0,0]

    for hrg in hrgList:
        avgList[0] += hrg
    avgList[0] /= len(hrgList)

    for hrgCrt in hrgCrtList:
        avgList[1] += hrgCrt
    avgList[1] /= len(hrgCrtList)

    for rng in rngList:
        avgList[2] += rng
    avgList[2] /= len(rngList)

    for rs in rsList:
        avgList[3] += rs
    avgList[3] /= len(rsList)

    for hog1 in hog1List:
        avgList[4] += hog1
    avgList[4] /= len(hog1List)

    for hog2 in hog2List:
        avgList[5] += hog2
    avgList[5] /= len(hog2List)
    
    return avgList

# %%
autoWholeAvgList = getMeanPercentageMetrics(autoDatesReadingListDict)
autoDayAvgList = getMeanPercentageMetrics(autoDayDict)
autoNightAvgList = getMeanPercentageMetrics(autoNightDict)
manWholeAvgList = getMeanPercentageMetrics(manDatesReadingListDict)
manDayAvgList = getMeanPercentageMetrics(manDayDict)
manNightAvgList = getMeanPercentageMetrics(manNightDict)
# print("AUTO whole day metrics = {}".format(autoWholeAvgList))
# print("AUTO daytime metrics = {}".format(autoDayAvgList))
# print("AUTO nighttime metrics = {}".format(autoNightAvgList))
# print("MANUAL whole day metrics = {}".format(manWholeAvgList))
# print("MANUAL daytime metrics = {}".format(manDayAvgList))
# print("MANUAL nighttime metrics = {}".format(manNightAvgList))
# Out:
# AUTO whole day metrics = [24.936342592592577, 5.680941358024692, 69.52546296296296, 54.57754629629632, 4.274691358024691, 1.2982253086419755]
# AUTO daytime metrics = [21.880787037037027, 5.264274691358025, 48.3738425925926, 36.111111111111114, 3.609182098765433, 1.105324074074074]
# AUTO nighttime metrics = [3.072625698324023, 0.41899441340782123, 21.26978584729982, 18.56959962756051, 0.6692271880819368, 0.19397889509621352]
# MANUAL whole day metrics = [32.8342013888889, 11.5234375, 54.75260416666668, 41.796875, 8.897569444444445, 1.8012152777777777]
# MANUAL daytime metrics = [28.255208333333336, 10.546875, 37.28298611111112, 28.86284722222222, 7.508680555555555, 1.8012152777777777]
# MANUAL nighttime metrics = [4.88425925925926, 1.0416666666666667, 18.634259259259256, 13.796296296296298, 1.4814814814814814, 0.0]
